# %% [markdown]
# <a href="https://colab.research.google.com/github/RebekahKnits/Coursera_files/blob/main/GDP_of_select_countries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project with Michael

# %% [markdown]
# ## Import data

# %%
import csv
from google.colab import drive
drive.mount('/content/drive', force_remount=True) # Add force_remount=True to explicitly request authentication

file_name = "/content/drive/My Drive/SpinoffR&E Collab/First_Data_2Oct2025.csv" # Update the file path to your Google Drive

with open(file_name, 'r') as file:
    reader = csv.reader(file)
    data = list(reader)

print("Data loaded successfully!") # Add a print statement to confirm data loading
# Out:
# Mounted at /content/drive
# Data loaded successfully!

# %% [markdown]
# ## Cleaning and sorting

# %%
import pandas as pd
df = pd.DataFrame(data)
df.columns = df.iloc[0]
df = df.iloc[1:]
df = df[df['Country Name'] != "World"]
df = df.drop('Series Code', axis=1)
df = df[df['Series Name'] != ""]
for year in range(1960, 2025):
    df= df.rename(columns={f'{year} [YR{year}]': f'{year}'})
df.head()
df.tail()
# Out:
# 0       Country Name Country Code  \
# 88          Ethiopia          ETH
# 89  Egypt, Arab Rep.          EGY
# 90  Egypt, Arab Rep.          EGY
# 91  Egypt, Arab Rep.          EGY
# 92  Egypt, Arab Rep.          EGY
#
# 0                                         Series Name         1960  \
# 88                                  Population, total     21376693
# 89                            GDP (constant 2015 US$)  20297834751
# 90       Energy use (kg of oil equivalent per capita)           ..
# 91  Energy use (kg of oil equivalent) per $1,000 G...           ..
# 92                                  Population, total     26896479
#
# 0          1961         1962         1963         1964         1965  \
# 88     21906102     22465126     23051637     23666548     24310612
# 89  21345429172  22172696194  24504840916  27324754469  28667504460
# 90           ..           ..           ..           ..           ..
# 91           ..           ..           ..           ..           ..
# 92     27600898     28337013     29091869     29858922     30629174
#
# 0          1966  ...         2015         2016         2017         2018  \
# 88     24952689  ...    103867135    106718162    109666481    112664152
# 89  30114182469  ...  3.29367E+11  3.43683E+11  3.58053E+11  3.77141E+11
# 90           ..  ...  809.4914492  872.3248081  895.9758895   870.566777
# 91           ..  ...  60.29321894  63.54662074  63.91445587  60.08794813
# 92     31406541  ...     99597342    101644589    103696057    105682094
#
# 0          2019         2020         2021         2022         2023  \
# 88    115737383    118917671    122138588    125384287    128691692
# 89  3.98081E+11  4.12213E+11  4.25778E+11  4.53827E+11  4.70892E+11
# 90  844.5405104  805.0208623  885.6778555  900.3733108           ..
# 91  56.20315275  52.58399981  56.85069266  55.03372891           ..
# 92    107553158    109315124    110957008    112618250    114535772
#
# 0         2024
# 88   132059767
# 89  4.8219E+11
# 90          ..
# 91          ..
# 92   116538258
#
# [5 rows x 68 columns]

# %%
import numpy as np
for year in range(1960, 2025):
  df[f'{year}']=df[f'{year}'].replace('..', np.nan)
  df[f'{year}']=pd.to_numeric(df[f'{year}'])
#df.dtypes

# %%
df.head()
# Out:
# 0 Country Name Country Code  \
# 1    Australia          AUS
# 2    Australia          AUS
# 3    Australia          AUS
# 4    Australia          AUS
# 5       Canada          CAN
#
# 0                                        Series Name          1960  \
# 1                            GDP (constant 2015 US$)  2.045560e+11
# 2       Energy use (kg of oil equivalent per capita)  3.063554e+03
# 3  Energy use (kg of oil equivalent) per $1,000 G...           NaN
# 4                                  Population, total  1.027648e+07
# 5                            GDP (constant 2015 US$)  2.763860e+11
#
# 0          1961          1962          1963          1964          1965  \
# 1  2.096340e+11  2.123470e+11  2.255470e+11  2.412910e+11  2.557200e+11
# 2  3.115787e+03  3.172975e+03  3.284051e+03  3.349414e+03  3.463216e+03
# 3           NaN           NaN           NaN           NaN           NaN
# 4  1.048300e+07  1.074200e+07  1.095000e+07  1.116700e+07  1.138800e+07
# 5  2.851290e+11  3.063070e+11  3.225340e+11  3.440020e+11  3.657330e+11
#
# 0          1966  ...          2015          2016          2017          2018  \
# 1  2.618040e+11  ...  1.351300e+12  1.388580e+12  1.420240e+12  1.461120e+12
# 2  3.546538e+03  ...  5.318667e+03  5.216989e+03  5.323929e+03  5.282207e+03
# 3           NaN  ...  9.550197e+01  9.259581e+01  9.392188e+01  9.194381e+01
# 4  1.165100e+07  ...  2.381600e+07  2.419091e+07  2.459259e+07  2.496326e+07
# 5  3.904550e+11  ...  1.556510e+12  1.572670e+12  1.620390e+12  1.664830e+12
#
# 0          2019          2020          2021          2022          2023  \
# 1  1.492850e+12  1.491060e+12  1.522540e+12  1.587130e+12  1.641760e+12
# 2  5.295872e+03  5.229063e+03  5.070767e+03  4.889621e+03  5.078218e+03
# 3  9.156537e+01  9.164189e+01  8.715303e+01  8.165203e+01  8.399142e+01
# 4  2.533483e+07  2.564925e+07  2.568541e+07  2.601440e+07  2.665278e+07
# 5  1.696610e+12  1.611130e+12  1.707000e+12  1.778500e+12  1.805690e+12
#
# 0          2024
# 1  1.665260e+12
# 2           NaN
# 3           NaN
# 4  2.720481e+07
# 5  1.833280e+12
#
# [5 rows x 68 columns]

# %% [markdown]
# ### Grouping Data

# %%
def fix_Series(name):
  match name:
    case "Energy use (kg of oil equivalent per capita)":
      return "Energy use per capita"
    case "Energy use (kg of oil equivalent) per $1,000 GDP (constant 2021 PPP)":
      return "Energy use per $1K GDP"
    case "GDP (constant 2015 US$)":
      return "GDP"
    case "Population, total":
      return "Population"

# %%
grouped_dfs = df.groupby('Series Name')
for name, group in grouped_dfs:
  #  print(f"Group Name: {fix_Series(name)}")
    series_df = pd.DataFrame(group)
    series_df = series_df.drop(['Series Name', 'Country Code'], axis=1)
    series_df = series_df.reset_index(drop=True)
  #  print(series_df)
   # print(series_df.head(4))
  #  print("\n")

# %% [markdown]
# ### Exporting to Excel (test)

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.12/dist-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl) (2.0.0)

# %%
import openpyxl
output_file = '/content/drive/My Drive/SpinoffR&E Collab/Pivoted_data.xlsx'

#work_book = openpyxl.Workbook()
#work_sheet = work_book.active
#for name, group in grouped_dfs:
#    sheet_name = name
#    group.to_excel(output_file,sheet_name=sheet_name, index=False, engine='openpyxl')
#work_book.save('test.xlsx')

with pd.ExcelWriter(output_file) as writer:
    for name, group in grouped_dfs:
        sheet_name = fix_Series(name)
        group = group.drop('Series Name', axis=1)
        group.to_excel(writer, sheet_name=sheet_name, index=False)

#df.to_excel(output_file,  index=False)

# %% [markdown]
# ## Setup Visualizations

# %% [markdown]
# ### old code verion
#
# import matplotlib.pyplot as plt
# import seaborn as sns
# import os
# from google.colab import drive
#
# drive.mount('/content/drive', force_remount=True) # Add force_remount=True to explicitly request authentication
#
# folder_name = "/content/drive/My Drive/SpinoffR&E Collab/Pies" # Update the file path to your Google Drive
#
#
# grouped_dfs = df.groupby('Series Name')
# for name, series_df in grouped_dfs:
#     series_name = fix_Series(name)
#
#     inner_folder_name = os.path.join(folder_name, series_name.replace(" ", "_"))
#     os.makedirs(inner_folder_name, exist_ok=True)
#
#     series_df = series_df.drop(['Series Name','Country Code'], axis=1)
#     series_df = series_df.set_index('Country Name')
#     series_df = series_df.apply(pd.to_numeric, errors='coerce')
#
#     for year in range(1960, 2025):
#     #for year in ['1990']:
#         year=str(year)
#
#         year_data = series_df[series_df[year].notna()]
#         if year_data.empty or year_data[year].sum()==0:
#             continue
#
#         chart_title = f'{series_name}- {year}'
#         labels = year_data.index
#         sizes = year_data[year]
#
#         # Create a pie chart
#         plt.figure(figsize=(10, 6))
#         plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
#         plt.title(chart_title)
#         plt.axis('equal')
#
#         safe_title = "".join(c for c in chart_title if c.isalnum() or c.isspace()).rstrip()
#         file_path = os.path.join(inner_folder_name, f'{safe_title}.png')
#         plt.savefig(file_path)
#         plt.close()

# %% [markdown]
# ### better code version

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import os
from google.colab import drive
from matplotlib.animation import FuncAnimation, PillowWriter


drive.mount('/content/drive', force_remount=True) # Add force_remount=True to explicitly request authentication
folder_name = "/content/drive/My Drive/SpinoffR&E Collab/Pies" # Update the file path to your Google Drive

grouped_dfs = df.groupby('Series Name')
for name, series_df in grouped_dfs:
  series_name = fix_Series(name)

  #ensure there are folders for each series and get the path for that folder
  inner_folder_name = os.path.join(folder_name, series_name.replace(" ", "_"))
  os.makedirs(inner_folder_name, exist_ok=True)

  #clean up the series information (probably should do this earlier)
  series_df = series_df.drop(['Series Name','Country Code'], axis=1)
  series_df = series_df.set_index('Country Name')
  series_df = series_df.apply(pd.to_numeric, errors='coerce')


  # Create a pie chart using fig, ax
  fig, ax = plt.subplots(figsize=(10, 6))

  for year in range(1960, 2025):
    ax.clear()
    year_str = str(year)

    # remove the empty countries
    year_data = series_df[series_df[year_str].notna()]

    # skip years if there is no data for that year at all
    if year_data.empty or year_data[year_str].sum()==0:
      continue

    chart_title = f'{series_name}: {year}'
    labels = year_data.index
    sizes = year_data[year_str]

    # Create pie chart on the ax object
    ax.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
    ax.set_title(chart_title)
    ax.axis('equal')  # Equal aspect ratio to ensure circle

    # Sanitize filename for individual years
    safe_title = "".join(c for c in chart_title if c.isalnum() or c.isspace()).rstrip()
    file_path = os.path.join(inner_folder_name, f'{safe_title}.png')

    # Save and close
    fig.savefig(file_path, bbox_inches='tight')
    plt.close(fig)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Animate IT!

# %%
import matplotlib.pyplot as plt

#animate function
def animate(year):
    ax.clear()
    year_str = str(year)

    if year_str not in series_df.columns:
      return

    # remove the empty countries
    year_data = series_df[series_df[year_str].notna()]

    # skip years if there is no data for that year at all
    if year_data.empty or year_data[year_str].sum()==0:
      return

    chart_title = f'{series_name}: {year}'
    labels = year_data.index
    sizes = year_data[year_str]

    # Create pie chart on the ax object
    ax.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
    ax.set_title(chart_title)
    ax.axis('equal')  # Equal aspect ratio to ensure circle

# %%
import matplotlib.pyplot as plt
import os
from google.colab import drive
from matplotlib.animation import FuncAnimation, PillowWriter


drive.mount('/content/drive', force_remount=True) # Add force_remount=True to explicitly request authentication
folder_name = "/content/drive/My Drive/SpinoffR&E Collab/Pies" # Update the file path to your Google Drive

grouped_dfs = df.groupby('Series Name')
for name, series_df in grouped_dfs:
  series_name = fix_Series(name)

  #ensure there are folders for each series and get the path for that folder
  inner_folder_name = os.path.join(folder_name, series_name.replace(" ", "_"))
  os.makedirs(inner_folder_name, exist_ok=True)

  #clean up the series information (probably should do this earlier)
  series_df = series_df.drop(['Series Name','Country Code'], axis=1)
  series_df = series_df.set_index('Country Name')
  series_df = series_df.apply(pd.to_numeric, errors='coerce')

  # Create a pie chart using fig, ax
  fig, ax = plt.subplots(figsize=(10, 6))

  valid_years = []
  for year in range(1960, 2025):
    year_str = str(year)
    if year_str in series_df.columns:
      year_data = series_df[series_df[year_str].notna()]
      if not year_data.empty and year_data[year_str].sum() > 0:
        valid_years.append(year)

  if not valid_years:
    print(f"No valid years found for {series_name}. Skipping...")
    plt.close(fig)
    continue

  #animate system
  animation = FuncAnimation(fig, animate, frames=valid_years, interval=500)
  gif_path = os.path.join(inner_folder_name, f'{series_name}.gif')
  animation.save(gif_path, writer='pillow')
  plt.close(fig)
# Out:
# Mounted at /content/drive
